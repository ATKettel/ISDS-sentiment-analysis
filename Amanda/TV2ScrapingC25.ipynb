# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import json
import re

# %%
# Scraper en enkelt side og returnerer artikellinks
def scrape_page(page_url):
    try:
        response = requests.get(page_url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        
        articles = []
        
        # Find alle li-elementer med den rigtige klasse
        for item in soup.find_all('li', class_='tc_searchresults__item__item'):
            link_tag = item.find('a', href=True)  # Find 'a'-tagget inde i 'li'-elementet
            if link_tag:
                article_url = link_tag['href']
                if not article_url.startswith('http'):
                    article_url = 'https://tv2.dk' + article_url
                
                # Brug regex til at finde datoen i formatet YYYY-MM-DD
                date_match = re.search(r'\d{4}-\d{2}-\d{2}', article_url)
                if date_match:
                    article_date = date_match.group(0)  # Udtræk datoen
                else:
                    article_date = "Unknown date"
                
                articles.append({"url": article_url, "date": article_date})
        
        return articles
    
    except Exception as e:
        print(f"An error occurred with URL: {page_url}")
        print(e)
        return []  # Returner en tom liste, hvis der er en fejl

# %%
def scrape_all_pages(base_url, search_query, max_pages):
    all_article_links = []

    for page_num in range(1, max_pages + 1):
        page_url = f"{base_url}?query={search_query}&sort=date&page={page_num}"
        print(f"Scraping page: {page_num} - {page_url}")

        articles_on_page = scrape_page(page_url)
        all_article_links.extend(articles_on_page)

        # Vent lidt for at undgå at blive blokeret
        time.sleep(2)

    return all_article_links

# %%
# Hovedfunktion til at scrappe alle artikler og gemme i en CSV-fil
def main():
    base_url = 'https://search.tv2.dk/'
    search_query = "c25"
    max_pages = 11

    # Scrape alle artikel-links
    all_article_links = scrape_all_pages(base_url, search_query, max_pages)

    # Scrape teksten fra hver artikel
    all_articles_text = []

    for idx, article_data in enumerate(all_article_links):
        article_url = article_data['url']  # Udtræk kun URL'en fra ordbogen
        article_date = article_data['date']
        
        print(f"Scraping article {idx + 1}/{len(all_article_links)}: {article_url}")
        
        # Sørg for at sende kun URL-strengen til scrape_article_text
        article_text = scrape_article_text(article_url)
        
        all_articles_text.append({
            "url": article_url,
            "text": article_text,
            "date": article_date
        })

        # Vent lidt mellem anmodninger for at undgå blokering
        time.sleep(2)

    # Gem resultaterne i en CSV-fil
    df = pd.DataFrame(all_articles_text)
    df.to_csv('tv2_c25_articles.csv', index=False)

    print(f"Scraping completed. Total articles scraped: {len(all_articles_text)}")

# %%
# Funktion til at scrappe teksten fra en artikel
def scrape_article_text(article_url):
    try:
        response = requests.get(article_url)  # article_url skal være en streng, ikke en ordbog
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Hent artiklens tekstindhold - tilpas selector afhængigt af HTML-strukturen
            paragraphs = soup.find_all('p')
            article_text = '\n'.join([para.text for para in paragraphs])
            return article_text
        else:
            print(f"Article not found (status code {response.status_code}): {article_url}")
            return "Article not found"
    
    except requests.exceptions.RequestException as e:
        print(f"An error occurred while scraping the article {article_url}: {e}")
        return "Error"

# %%
# Kør hovedfunktionen
if __name__ == "__main__":
    main()
# Out:
# Scraping page: 1 - https://search.tv2.dk/?query=c25&sort=date&page=1
# Scraping page: 2 - https://search.tv2.dk/?query=c25&sort=date&page=2
# Scraping page: 3 - https://search.tv2.dk/?query=c25&sort=date&page=3
# Scraping page: 4 - https://search.tv2.dk/?query=c25&sort=date&page=4
# Scraping page: 5 - https://search.tv2.dk/?query=c25&sort=date&page=5
# Scraping page: 6 - https://search.tv2.dk/?query=c25&sort=date&page=6
# Scraping page: 7 - https://search.tv2.dk/?query=c25&sort=date&page=7
# Scraping page: 8 - https://search.tv2.dk/?query=c25&sort=date&page=8
# Scraping page: 9 - https://search.tv2.dk/?query=c25&sort=date&page=9
# Scraping page: 10 - https://search.tv2.dk/?query=c25&sort=date&page=10
# Scraping page: 11 - https://search.tv2.dk/?query=c25&sort=date&page=11
# Scraping article 1/100: https://nyheder.tv2.dk/penge/2024-08-14-inflationen-i-usa-overrasker-det-kan-betyde-lavere-renter-i-hele-europa
# Scraping article 2/100: https://nyheder.tv2.dk/live/kort-nyt/ejere-bekraefter-forhandlinger-om-salg-af-superligaklub?entry=9b95a58f-deac-4050-b8de-b29844454eea
# Scraping article 3/100: https://nyheder.tv2.dk/video/2024-08-06-danske-aktier-i-modreaktion-6359975587112
# Scraping article 4/100: https://nyheder.tv2.dk/live/business/2024-08-06-foelg-udviklingen-paa-aktiemarkedet
# Scraping article 5/100: https://nyheder.tv2.dk/business/2024-08-06-aktie-nedtur-kan-blive-gevinst-for-boligejerne-det-loeber-maaske-op-i-en-pose-fredagsslik
# Scraping article 6/100: https://nyheder.tv2.dk/udland/2024-08-06-japanske-aktier-goer-halvt-comeback-efter-historisk-fald
# Scraping article 7/100: https://nyheder.tv2.dk/live/business/2024-08-05-aktiemarkeder-med-blodroede-tal
# Scraping article 8/100: https://nyheder.tv2.dk/business/2024-08-05-store-kursfald-kan-vaere-gave-til-boligejere-her-er-svarene-paa-centrale-spoergsmaal
# Scraping article 9/100: https://nyheder.tv2.dk/2024-08-05-dagens-overblik-store-danske-aktier-ramt-af-fjerdestoerste-fald-nogensinde
# Scraping article 10/100: https://nyheder.tv2.dk/business/2024-08-05-hoejt-at-flyve-dybt-at-falde-derfor-dykker-aktierne
# Scraping article 11/100: https://nyheder.tv2.dk/business/2024-08-05-hoejt-at-flyve-dybt-at-falde-derfor-dykker-aktierne
# Scraping article 12/100: https://nyheder.tv2.dk/penge/2024-08-03-chefstrateg-med-raad-til-hobbyinvestorer-efter-aktiedyk
# Scraping article 13/100: https://nyheder.tv2.dk/udland/2024-08-02-amerikanske-mastodonter-i-stort-kursfald
# Scraping article 14/100: https://nyheder.tv2.dk/business/2024-08-02-danske-aktier-i-voldsomt-fald
# Scraping article 15/100: https://nyheder.tv2.dk/business/2024-07-05-betyder-tiltalen-noget-for-nordeas-kunder-her-er-seks-spoergsmaal-om-og-svar-paa-anklagerne-mod-nordea
# Scraping article 16/100: https://nyheder.tv2.dk/video/RW1xMURjU20yT2c0UDJzdE9lVmhhRTZTeWl5Mk5OTXc
# Article not found (status code 404): https://nyheder.tv2.dk/video/RW1xMURjU20yT2c0UDJzdE9lVmhhRTZTeWl5Mk5OTXc
# Scraping article 17/100: https://nyheder.tv2.dk/2024-05-02-dagens-overblik-kongen-kommer-kvinde-til-hjaelp-ved-kronborg
# Scraping article 18/100: https://nyheder.tv2.dk/business/2024-05-02-dansk-oekonomi-slaar-vores-naboer-med-laengder
# Scraping article 19/100: https://nyheder.tv2.dk/samfund/2024-04-22-flere-indberetter-til-whistleblowerordninger-i-danske-virksomheder
# Scraping article 20/100: https://nyheder.tv2.dk/live/udland/2024-04-15-iran-angriber-israel
# Scraping article 21/100: https://nyheder.tv2.dk/business/2024-03-26-broulykke-skaerer-milliarder-af-maersk-aktien
# Scraping article 22/100: https://omtv2.tv2.dk/media/ifcg1i3o/6369605-tv2-ansvarlighedsrapport-2023.pdf
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Scraping article 23/100: https://nyheder.tv2.dk/business/2024-02-26-medicinalfirmas-aktier-brager-i-vejret-efter-testresultater-paa-fedtlever
# Scraping article 24/100: https://nyheder.tv2.dk/business/2024-01-31-novo-nordisk-smadrer-egne-rekorder-tjener-halvanden-milliard-om-ugen
# Scraping article 25/100: https://nyheder.tv2.dk/penge/2024-01-11-skatterabat-skjuler-den-virkelige-vaerdi-af-dronningens-loen
# Scraping article 26/100: https://nyheder.tv2.dk/live/2023-12-29-kort-nyt
# Scraping article 27/100: https://nyheder.tv2.dk/live/2023-12-27-kort-nyt
# Scraping article 28/100: https://nyheder.tv2.dk/live/2023-12-14-kort-nyt
# Scraping article 29/100: https://nyheder.tv2.dk/2023-10-24-c25-virksomhed-indgaar-milliardaftale-om-saudisk-fremtidsby
# Scraping article 30/100: https://nyheder.tv2.dk/business/2023-10-24-dansk-virksomhed-skal-spille-noeglerolle-i-kontroversielt-megaprojekt-vi-foerer-ikke-politik
# Scraping article 31/100: https://nyheder.tv2.dk/business/2023-10-20-flere-elitevirksomheder-vaelger-kvinder-til-bestyrelserne-men-ikke-til-de-tunge-poster
# Scraping article 32/100: https://nyheder.tv2.dk/business/2023-10-23-tidligere-topchef-paa-ny-mission-der-skal-flere-kvinder-i-toppen-af-de-store-virksomheder
# Scraping article 33/100: https://nyheder.tv2.dk/politik/2023-08-31-alex-v-fastholder-ultimatum-nogle-gange-skal-man-staa-fast
# Scraping article 34/100: https://nyheder.tv2.dk/business/2023-08-30-oersted-aktien-falder-dramatisk
# Scraping article 35/100: https://nyheder.tv2.dk/business/2023-07-07-coloplast-vil-koebe-islandsk-selskab-for-op-til-89-milliarder
# Scraping article 36/100: https://nyheder.tv2.dk/business/2023-06-30-dansker-bliver-topchef-i-heathrow
# Scraping article 37/100: https://nyheder.tv2.dk/business/2023-05-08-flere-i-danmarks-stoerste-virksomheder-bruger-whistleblowerordninger-men-det-er-ikke-udelukkende-godt-mener-ekspert
# Scraping article 38/100: https://nyheder.tv2.dk/2023-03-30-nyhedsoverblik
# Scraping article 39/100: https://nyheder.tv2.dk/business/2023-03-16-credit-suisse-faar-tilsagn-om-laan-paa-380-milliarder-kroner
# Scraping article 40/100: https://nyheder.tv2.dk/business/2023-03-15-nationalbank-klar-til-at-redde-storbank-efter-dramatisk-fald
# Scraping article 41/100: https://nyheder.tv2.dk/2023-03-13-flere-i-kritisk-tilstand-efter-bil-paakoerer-folkemaengde-i-quebec
# Scraping article 42/100: https://nyheder.tv2.dk/business/2023-03-13-nationalbanken-udtaler-sig-om-danske-risici-efter-amerikansk-bankkrak
# Scraping article 43/100: https://nyheder.tv2.dk/business/2023-03-13-amerikanske-banker-styrtbloeder-paa-boersen-efter-krak
# Scraping article 44/100: https://nyheder.tv2.dk/business/2023-01-07-2022-var-et-dyrt-aktieaar-alligevel-tror-mange-danskere-at-de-kan-slaa-markedet
# Scraping article 45/100: https://nyheder.tv2.dk/business/2023-01-03-2022-var-et-raedselsaar-for-aktiemarkedet-men-eksperter-spaar-bedre-tider
# Scraping article 46/100: https://nyheder.tv2.dk/business/2022-12-30-hver-dansker-har-i-gennemsnit-tabt-300000-kroner-i-aar-viser-ny-beregning
# Scraping article 47/100: https://nyheder.tv2.dk/business/2022-12-30-inflationen-taber-fart-men-vi-bliver-ikke-meget-rigere-her-er-12-oekonomers-forventninger-til-2023
# Scraping article 48/100: https://nyheder.tv2.dk/business/2022-12-12-stor-dansk-fusion-chr-hansen-og-novozymes-gaar-sammen
# Scraping article 49/100: https://nyheder.tv2.dk/business/2022-11-11-amerikansk-melding-udloeste-aktiefest-men-var-det-et-bump-paa-vejen-eller-starten-paa-noget-stort
# Scraping article 50/100: https://nyheder.tv2.dk/business/2022-10-13-i-usa-fortsaetter-inflationen-nedad-men-renterne-vil-stadig-stige-forventer-oekonomer
# Scraping article 51/100: https://nyheder.tv2.dk/business/2022-10-10-investeringskurven-er-knaekket-men-saerligt-to-grupper-har-is-i-maven-og-holder-fast
# Scraping article 52/100: https://nyheder.tv2.dk/business/2022-10-09-danskerne-har-kastet-milliarder-i-aktiemarkedet-nu-knaekker-kurven
# Scraping article 53/100: https://nyheder.tv2.dk/business/2022-09-30-danske-aktier-har-kurs-mod-vaerste-maaned-i-11-aar
# Scraping article 54/100: https://nyheder.tv2.dk/samfund/2022-09-21-de-stigende-priser-kan-skabe-politisk-ustabilitet-siger-eksperter
# Scraping article 55/100: https://nyheder.tv2.dk/samfund/2022-09-21-handelsbanken-i-ny-dyster-prognose-dansk-oekonomi-er-paa-vej-ned-i-et-sort-hul
# Scraping article 56/100: https://nyheder.tv2.dk/penge/2022-09-20-c25-indekset-saetter-bundrekord-for-2022
# Scraping article 57/100: https://nyheder.tv2.dk/2022-09-20-dagens-nyheder-20-september
# Scraping article 58/100: https://omtv2.tv2.dk/media/dgdg00v1/tv-2-ansvarlighedsrapport-2022.pdf
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Scraping article 59/100: https://nyheder.tv2.dk/samfund/2022-09-05-danskere-advares-om-stor-ekstraregning-efter-russisk-gasstop
# Scraping article 60/100: https://nyheder.tv2.dk/samfund/2022-09-01-danske-aktier-falder-markant-efter-meldinger-om-stigende-renter
# Scraping article 61/100: https://nyheder.tv2.dk/business/2022-08-10-overblik-hvad-betyder-inflationen-for-danmarks-oekonomi
# Scraping article 62/100: https://nyheder.tv2.dk/samfund/2022-08-02-flere-virksomheder-vil-betale-maend-for-at-gaa-hjemme-i-24-uger-vi-taenker-at-det-kan-blive-en-god-forretning
# Scraping article 63/100: https://nyheder.tv2.dk/penge/2022-07-31-efter-raedselsmaaneder-ser-det-danske-aktiemarked-ud-til-at-vende-men-pas-paa-med-investeringerne
# Scraping article 64/100: https://nyheder.tv2.dk/business/2022-07-28-vestas-aktien-brager-op-stiger-159-procent
# Scraping article 65/100: https://vejr.tv2.dk/video/TWloMkY5X1Y0SmpfekZuRTRlWFhHM1VmRkVYckg5dVc
# Article not found (status code 404): https://vejr.tv2.dk/video/TWloMkY5X1Y0SmpfekZuRTRlWFhHM1VmRkVYckg5dVc
# Scraping article 66/100: https://nyheder.tv2.dk/video/dXJuOnR2MjpjbXM6YnJpZ2h0Y292ZTp2aWRlbzo2MzA5MDYzMzczMTEy
# Article not found (status code 404): https://nyheder.tv2.dk/video/dXJuOnR2MjpjbXM6YnJpZ2h0Y292ZTp2aWRlbzo2MzA5MDYzMzczMTEy
# Scraping article 67/100: https://nyheder.tv2.dk/video/clE3X3ExRnhlM2dyaXFpTmVwcjZuWGQzT0hDS3RHV1Q
# Article not found (status code 404): https://nyheder.tv2.dk/video/clE3X3ExRnhlM2dyaXFpTmVwcjZuWGQzT0hDS3RHV1Q
# Scraping article 68/100: https://livsstil.tv2.dk/video/SlhfMmxiQTJPNWJOTDhuYUhrSFU5YVUyRUFuSEpGUzQ
# Article not found (status code 404): https://livsstil.tv2.dk/video/SlhfMmxiQTJPNWJOTDhuYUhrSFU5YVUyRUFuSEpGUzQ
# Scraping article 69/100: https://livsstil.tv2.dk/video/OElfcDZJUjJvUW5OSjFxWHJUbkdlb1IyRWJfZm93UXU
# Article not found (status code 404): https://livsstil.tv2.dk/video/OElfcDZJUjJvUW5OSjFxWHJUbkdlb1IyRWJfZm93UXU
# Scraping article 70/100: https://nyheder.tv2.dk/video/RG5LV0JVYmtiRGxwOFBOODF6TjdyYTU4OFZWczBHb0M
# Article not found (status code 404): https://nyheder.tv2.dk/video/RG5LV0JVYmtiRGxwOFBOODF6TjdyYTU4OFZWczBHb0M
# Scraping article 71/100: https://nyheder.tv2.dk/video/WUh5eUx2c1RyMzRDUXA1d2hrZTBRR1R2R0g5SG80dUU
# Article not found (status code 404): https://nyheder.tv2.dk/video/WUh5eUx2c1RyMzRDUXA1d2hrZTBRR1R2R0g5SG80dUU
# Scraping article 72/100: https://nyheder.tv2.dk/2022-06-16-juridisk-faderloese-kraever-erstatning-af-den-danske-stat
# Scraping article 73/100: https://nyheder.tv2.dk/business/2022-06-16-c25-indekset-i-stort-fald
# Scraping article 74/100: https://nyheder.tv2.dk/business/2022-06-14-mandag-skete-der-noget-paa-aktiemarkedet-der-ellers-kun-sker-ekstremt-sjaeldent
# Scraping article 75/100: https://nyheder.tv2.dk/business/2022-06-13-udskiftning-i-dansk-elite-aktieindeks
# Scraping article 76/100: https://nyheder.tv2.dk/2022-05-30-sydossetiens-leder-afviser-afstemning-om-indlemmelse-i-rusland
# Scraping article 77/100: https://nyheder.tv2.dk/business/2022-05-30-danske-aktier-er-taet-paa-rekordgod-dag
# Scraping article 78/100: https://nyheder.tv2.dk/business/2022-05-30-danske-aktier-hamrer-op
# Scraping article 79/100: https://nyheder.tv2.dk/penge/2022-05-24-inflation-kapper-milliarder-af-vores-opsparing
# Scraping article 80/100: https://nyheder.tv2.dk/business/2022-05-19-inflation-og-regnskaber-udloeser-stor-aktienedtur-i-usa
# Scraping article 81/100: https://nyheder.tv2.dk/business/2022-05-19-inflation-og-regnskaber-udloeser-stor-aktienedtur-i-usa
# Scraping article 82/100: https://nyheder.tv2.dk/business/2022-05-09-danske-aktier-i-stort-fald
# Scraping article 83/100: https://nyheder.tv2.dk/business/2022-05-09-de-danske-aktier-styrtbloeder-og-aarsagen-er-ikke-krigen-i-ukraine
# Scraping article 84/100: https://nyheder.tv2.dk/samfund/2022-05-03-medie-aktiehandlers-fejl-staar-bag-massive-fald-mandag
# Scraping article 85/100: https://nyheder.tv2.dk/2022-05-02-dagens-nyheder-2-maj-2022
# Scraping article 86/100: https://nyheder.tv2.dk/business/2022-05-02-klummergoej-skar-135-milliarder-af-det-danske-aktiemarked-paa-faa-minutter
# Scraping article 87/100: https://nyheder.tv2.dk/business/2022-02-25-danske-aktier-ryster-russisk-chok-af-sig-og-stiger-til-vejrs
# Scraping article 88/100: https://nyheder.tv2.dk/business/2022-02-25-krigen-i-ukraine-kan-ramme-din-privatoekonomi-her-er-eksperternes-raad
# Scraping article 89/100: https://nyheder.tv2.dk/samfund/2022-02-24-danske-aktier-styrtdykkede-efter-russisk-angreb-nu-stiger-de
# Scraping article 90/100: https://nyheder.tv2.dk/penge/2022-01-27-danske-investorer-koeber-aktier-naar-de-falder-men-er-det-klogt
# Scraping article 91/100: https://nyheder.tv2.dk/2022-01-24-dagens-nyheder-24-januar-2022
# Scraping article 92/100: https://nyheder.tv2.dk/business/2022-01-07-historisk-lav-ledighed-det-er-en-dansk-oekonomi-paa-energidrik-og-proteinbarer
# Scraping article 93/100: https://nyheder.tv2.dk/samfund/2022-01-06-dagens-nyheder-6-januar
# Scraping article 94/100: https://nyheder.tv2.dk/business/2022-01-06-c25-tager-kaempe-dyk-det-rusmiddel-vi-har-vaeret-vant-til-forsvinder
# Scraping article 95/100: https://nyheder.tv2.dk/penge/2021-12-30-saa-meget-er-din-formue-vokset-i-aar-og-her-er-farerne-for-naeste-aar
# Scraping article 96/100: https://nyheder.tv2.dk/business/2021-12-20-novo-aktien-i-kaempe-fald
# Scraping article 97/100: https://nyheder.tv2.dk/business/2021-12-20-dyr-dag-for-novo-aktionaerer-taber-mandag-117-procent
# Scraping article 98/100: https://nyheder.tv2.dk/samfund/2021-12-07-dagens-nyheder-7-december-2021
# Scraping article 99/100: https://nyheder.tv2.dk/business/2021-12-07-omikron-lettelse-sendte-danske-aktier-nordover
# Scraping article 100/100: https://nyheder.tv2.dk/samfund/2021-11-24-dagens-nyheder-24-november-2021
# Scraping completed. Total articles scraped: 100
