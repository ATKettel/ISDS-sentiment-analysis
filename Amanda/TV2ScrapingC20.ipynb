# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import json
import re

# %%
# Scraper en enkelt side og returnerer artikellinks
def scrape_page(page_url):
    try:
        response = requests.get(page_url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        
        articles = []
        
        # Find alle li-elementer med den rigtige klasse
        for item in soup.find_all('li', class_='tc_searchresults__item__item'):
            link_tag = item.find('a', href=True)  # Find 'a'-tagget inde i 'li'-elementet
            if link_tag:
                article_url = link_tag['href']
                if not article_url.startswith('http'):
                    article_url = 'https://tv2.dk' + article_url
                
                # Brug regex til at finde datoen i formatet YYYY-MM-DD
                date_match = re.search(r'\d{4}-\d{2}-\d{2}', article_url)
                if date_match:
                    article_date = date_match.group(0)  # Udtræk datoen
                else:
                    article_date = "Unknown date"
                
                articles.append({"url": article_url, "date": article_date})
        
        return articles
    
    except Exception as e:
        print(f"An error occurred with URL: {page_url}")
        print(e)
        return []  # Returner en tom liste, hvis der er en fejl

# %%
def scrape_all_pages(base_url, search_query, max_pages):
    all_article_links = []

    for page_num in range(1, max_pages + 1):
        page_url = f"{base_url}?query={search_query}&sort=date&page={page_num}"
        print(f"Scraping page: {page_num} - {page_url}")

        articles_on_page = scrape_page(page_url)
        all_article_links.extend(articles_on_page)

        # Vent lidt for at undgå at blive blokeret
        time.sleep(2)

    return all_article_links

# %%
# Hovedfunktion til at scrappe alle artikler og gemme i en CSV-fil
def main():
    base_url = 'https://search.tv2.dk/'
    search_query = "c20"
    max_pages = 11

    # Scrape alle artikel-links
    all_article_links = scrape_all_pages(base_url, search_query, max_pages)

    # Scrape teksten fra hver artikel
    all_articles_text = []

    for idx, article_data in enumerate(all_article_links):
        article_url = article_data['url']  # Udtræk kun URL'en fra ordbogen
        article_date = article_data['date']
        
        print(f"Scraping article {idx + 1}/{len(all_article_links)}: {article_url}")
        
        # Sørg for at sende kun URL-strengen til scrape_article_text
        article_text = scrape_article_text(article_url)
        
        all_articles_text.append({
            "url": article_url,
            "text": article_text,
            "date": article_date
        })

        # Vent lidt mellem anmodninger for at undgå blokering
        time.sleep(2)

    # Gem resultaterne i en CSV-fil
    df = pd.DataFrame(all_articles_text)
    df.to_csv('tv2_c20_articles.csv', index=False)

    print(f"Scraping completed. Total articles scraped: {len(all_articles_text)}")

# %%
# Funktion til at scrappe teksten fra en artikel
def scrape_article_text(article_url):
    try:
        response = requests.get(article_url)  # article_url skal være en streng, ikke en ordbog
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Hent artiklens tekstindhold - tilpas selector afhængigt af HTML-strukturen
            paragraphs = soup.find_all('p')
            article_text = '\n'.join([para.text for para in paragraphs])
            return article_text
        else:
            print(f"Article not found (status code {response.status_code}): {article_url}")
            return "Article not found"
    
    except requests.exceptions.RequestException as e:
        print(f"An error occurred while scraping the article {article_url}: {e}")
        return "Error"

# %%
# Kør hovedfunktionen
if __name__ == "__main__":
    main()
# Out:
# Scraping page: 1 - https://search.tv2.dk/?query=c20&sort=date&page=1
# Scraping page: 2 - https://search.tv2.dk/?query=c20&sort=date&page=2
# Scraping page: 3 - https://search.tv2.dk/?query=c20&sort=date&page=3
# Scraping page: 4 - https://search.tv2.dk/?query=c20&sort=date&page=4
# Scraping page: 5 - https://search.tv2.dk/?query=c20&sort=date&page=5
# Scraping page: 6 - https://search.tv2.dk/?query=c20&sort=date&page=6
# Scraping page: 7 - https://search.tv2.dk/?query=c20&sort=date&page=7
# Scraping page: 8 - https://search.tv2.dk/?query=c20&sort=date&page=8
# Scraping page: 9 - https://search.tv2.dk/?query=c20&sort=date&page=9
# Scraping page: 10 - https://search.tv2.dk/?query=c20&sort=date&page=10
# Scraping page: 11 - https://search.tv2.dk/?query=c20&sort=date&page=11
# Scraping article 1/100: https://nyheder.tv2.dk/business/2024-02-26-medicinalfirmas-aktier-brager-i-vejret-efter-testresultater-paa-fedtlever
# Scraping article 2/100: https://nyheder.tv2.dk/video/dXJuOnR2MjpjbXM6YnJpZ2h0Y292ZTp2aWRlbzo2MzA4OTU5MTA3MTEy
# Article not found (status code 404): https://nyheder.tv2.dk/video/dXJuOnR2MjpjbXM6YnJpZ2h0Y292ZTp2aWRlbzo2MzA4OTU5MTA3MTEy
# Scraping article 3/100: https://nyheder.tv2.dk/video/TGxfWjJfYTd5OW9hcTRDeDQ0Y2haalhEcHpyWTRkU3E
# Article not found (status code 404): https://nyheder.tv2.dk/video/TGxfWjJfYTd5OW9hcTRDeDQ0Y2haalhEcHpyWTRkU3E
# Scraping article 4/100: https://nyheder.tv2.dk/video/dVlUQ3dyekNUWkw4OWd5NGxDeTFNSWphdjhhR0swWlg
# Article not found (status code 404): https://nyheder.tv2.dk/video/dVlUQ3dyekNUWkw4OWd5NGxDeTFNSWphdjhhR0swWlg
# Scraping article 5/100: https://nyheder.tv2.dk/video/dXJuOnR2MjpjbXM6YnJpZ2h0Y292ZTp2aWRlbzo2MzA4ODg0Mzk3MTEy
# Article not found (status code 404): https://nyheder.tv2.dk/video/dXJuOnR2MjpjbXM6YnJpZ2h0Y292ZTp2aWRlbzo2MzA4ODg0Mzk3MTEy
# Scraping article 6/100: https://nyheder.tv2.dk/business/2017-12-05-c20-indekset-udvides-her-er-de-5-nye-virksomheder
# Scraping article 7/100: https://nyheder.tv2.dk/business/2017-01-06-vice-direktoer-stopper-i-c20-selskab
# Scraping article 8/100: https://nyheder.tv2.dk/business/2016-12-14-maersk-overhaler-genmab-som-aarets-mest-stigende-i-c20
# Scraping article 9/100: https://nyheder.tv2.dk/business/2016-12-06-2016-er-en-fuser-for-c20-indekset
# Scraping article 10/100: http://omtv2.tv2.dk/nyhedsartikler/nyhedsvisning/operation-x-kursuskongens-beskidte-metoder/
# Scraping article 11/100: http://omtv2.tv2.dk/nyhedsartikler/nyhedsvisning/operation-x-kursuskongens-beskidte-metoder/
# Scraping article 12/100: https://nyheder.tv2.dk/business/2016-06-20-comeback-aktie-rammer-bunden-paa-foerste-dag-i-c20
# Scraping article 13/100: https://nyheder.tv2.dk/business/2016-06-10-dong-kommer-ikke-i-c20
# Scraping article 14/100: https://nyheder.tv2.dk/business/2016-06-09-dong-kan-snyde-foran-i-c20-koeen
# Scraping article 15/100: https://nyheder.tv2.dk/business/2016-02-10-danske-c20-aktier-i-historisk-stigning
# Scraping article 16/100: https://nyheder.tv2.dk/business/2016-02-08-c20-aktier-falder-kraftigt
# Scraping article 17/100: https://nyheder.tv2.dk/business/2015-11-13-regnskabssaeson-har-skuffet-c20-investorer
# Scraping article 18/100: https://nyheder.tv2.dk/business/2015-07-24-vestas-flyver-og-tager-c20-med-mod-himlen
# Scraping article 19/100: https://nyheder.tv2.dk/business/2015-03-08-guldregn-over-topchefer-i-c20-selskaberne
# Scraping article 20/100: https://nyheder.tv2.dk/business/2015-02-20-novo-nordisk-sender-c20-til-vejrs-til-ny-rekord
# Scraping article 21/100: https://nyheder.tv2.dk/business/2014-01-27-c20-cap-faldt-igen
# Scraping article 22/100: https://nyheder.tv2.dk/business/2013-06-13-nedtur-samtlige-c20aktier-falder
# Scraping article 23/100: https://nyheder.tv2.dk/business/2013-05-31-saadan-klarede-c20aktierne-sig-i-maj
# Scraping article 24/100: https://nyheder.tv2.dk/business/2013-05-28-c20indekset-i-rekord
# Scraping article 25/100: https://nyheder.tv2.dk/business/2013-02-04-c20indekset-skifter-navn
# Scraping article 26/100: https://nyheder.tv2.dk/2013-02-01-ny-rekord-for-c20aktier
# Scraping article 27/100: https://nyheder.tv2.dk/business/2012-11-09-c20-i-stoerste-stigning-i-over-et-aar
# Scraping article 28/100: https://nyheder.tv2.dk/2012-09-28-saadan-gik-det-aktierne-i-c20-i-september
# Scraping article 29/100: https://nyheder.tv2.dk/2012-08-15-c20-over-500-foerste-gang-i-5-aar
# Scraping article 30/100: https://nyheder.tv2.dk/business/2012-08-14-eksperter-c20-indeks-er-ubrugeligt
# Scraping article 31/100: https://nyheder.tv2.dk/business/2012-05-22-topdanmark-gaar-til-tops-i-c20
# Scraping article 32/100: https://nyheder.tv2.dk/business/2012-03-21-c20-klaeber-sig-til-gaarsdagens-slutniveau
# Scraping article 33/100: https://nyheder.tv2.dk/2011-09-27-c20-i-stoerste-stigning-i-over-1-aar
# Scraping article 34/100: https://nyheder.tv2.dk/business/2011-09-23-c20indekset-rammer-bundniveau
# Scraping article 35/100: https://nyheder.tv2.dk/business/2011-09-13-aktier-c20-banket-tilbage-i-2009niveau
# Scraping article 36/100: https://nyheder.tv2.dk/2011-09-05-dansk-c20indeks-er-styrtdykket
# Scraping article 37/100: https://nyheder.tv2.dk/2011-08-08-se-listen-over-de-stoerste-tabere-paa-c20
# Scraping article 38/100: https://nyheder.tv2.dk/business/2010-12-13-aktier-kl-1301-fls-i-front-af-c20-efter-rekord-kobberpris
# Scraping article 39/100: https://nyheder.tv2.dk/2010-12-02-tre-nye-aktier-stryger-ind-paa-c20indeks
# Scraping article 40/100: https://nyheder.tv2.dk/business/2010-12-02-polsk-retssag-baerer-gn-store-nord-i-c20
# Scraping article 41/100: https://nyheder.tv2.dk/business/2010-11-01-aktier-novo-og-vestas-presser-c20
# Scraping article 42/100: https://nyheder.tv2.dk/business/2010-10-25-aktier-vestas-i-minus-trods-positivt-c20
# Scraping article 43/100: https://nyheder.tv2.dk/business/2010-10-14-aktier-apm-og-novo-traekker-c20-i-minus
# Scraping article 44/100: https://nyheder.tv2.dk/business/2010-08-27-aktier-amerikansk-vaeksttal-sender-c20-i-plus
# Scraping article 45/100: https://nyheder.tv2.dk/business/2010-08-04-aktier-maersk-agerer-bundprop-i-svagt-c20
# Scraping article 46/100: https://nyheder.tv2.dk/business/2010-05-17-bankaktier-trykker-c20indekset
# Scraping article 47/100: https://nyheder.tv2.dk/2010-05-10-aktiefesten-fortsatte-til-c20lukningen
# Scraping article 48/100: https://nyheder.tv2.dk/business/2010-04-28-graesk-syge-lammer-c20
# Scraping article 49/100: https://nyheder.tv2.dk/business/2010-03-31-aktier-kl-930-c20-aabner-med-lille-minus-med-fokus-paa-vestas
# Scraping article 50/100: https://nyheder.tv2.dk/business/2010-03-22-aktier-kun-lundbeck-i-plus-i-c20
# Scraping article 51/100: https://nyheder.tv2.dk/business/2010-03-22-aktier-kun-lundbeck-i-plus-i-c20
# Scraping article 52/100: https://nyheder.tv2.dk/business/2010-03-18-aktier-gode-enkeltpraestationer-holder-c20-i-plus
# Scraping article 53/100: https://nyheder.tv2.dk/business/2010-03-17-aktier-carlsberg-og-novo-sikrede-c20plus
# Scraping article 54/100: https://nyheder.tv2.dk/business/2010-03-09-aktier-roedt-c20-ramt-af-gevinsthjemtagning
# Scraping article 55/100: https://nyheder.tv2.dk/business/2010-03-09-aktier-alt-er-roedt-i-c20
# Scraping article 56/100: https://nyheder.tv2.dk/business/2010-03-08-aktier-kursfald-i-maersk-traekker-c20-mod-status-quo
# Scraping article 57/100: https://nyheder.tv2.dk/business/2010-03-01-aktier-dsv-forrest-i-solid-start-paa-ugen-for-c20
# Scraping article 58/100: https://nyheder.tv2.dk/business/2010-02-12-aktier-c20-i-ligevaegt
# Scraping article 59/100: https://nyheder.tv2.dk/business/2010-02-10-aktier-vestas-kostede-minus-i-c20
# Scraping article 60/100: https://nyheder.tv2.dk/business/2010-02-05-aktier-fald-til-samtlige-c20selskaber
# Scraping article 61/100: https://nyheder.tv2.dk/business/2010-01-22-aktier-cykliske-selskaber-staar-for-skud-i-c20
# Scraping article 62/100: https://nyheder.tv2.dk/business/2010-01-21-aktier-store-drenge-presser-c20
# Scraping article 63/100: https://nyheder.tv2.dk/business/2010-01-19-aktier-c20-i-staerkt-comeback
# Scraping article 64/100: https://nyheder.tv2.dk/business/2010-01-14-aktier-rederier-og-flsmidth-hjaelper-c20-mod-2008niveau
# Scraping article 65/100: https://nyheder.tv2.dk/business/2010-01-11-aktier-c20-giver-resten-af-europa-baghjul
# Scraping article 66/100: https://nyheder.tv2.dk/business/2009-12-28-vestasinvestorer-loefter-c20
# Scraping article 67/100: https://nyheder.tv2.dk/business/2009-12-28-aktier-c20-i-stille-stigning
# Scraping article 68/100: https://nyheder.tv2.dk/business/2009-12-23-aktier-c20-paa-blandet-juleferie
# Scraping article 69/100: https://nyheder.tv2.dk/business/2009-12-23-aktier-flsmidth-holder-c20-i-plus
# Scraping article 70/100: https://nyheder.tv2.dk/business/2009-12-21-aktier-c20-tabt-bag-den-europaeiske-vogn
# Scraping article 71/100: https://nyheder.tv2.dk/business/2009-12-10-c20-tom-ordrebog-saenker-vestas
# Scraping article 72/100: https://nyheder.tv2.dk/business/2009-12-09-aktier-c20-ubeslutsomt-fra-start
# Scraping article 73/100: https://nyheder.tv2.dk/business/2009-12-03-aktier-svaervaegtere-tyngede-c20
# Scraping article 74/100: https://nyheder.tv2.dk/business/2009-12-03-aktier-novo-holder-c20-tilbage
# Scraping article 75/100: https://nyheder.tv2.dk/business/2009-11-06-aktier-dramafrit-c20
# Scraping article 76/100: https://nyheder.tv2.dk/business/2009-11-02-c20-danske-bank-steg-paa-forventniger
# Scraping article 77/100: https://nyheder.tv2.dk/business/2009-11-02-aktier-danske-bank-forrest-i-c20-forud-for-regnskab
# Scraping article 78/100: https://nyheder.tv2.dk/business/2009-10-30-aktier-c20-kan-have-noget-til-gode
# Scraping article 79/100: https://nyheder.tv2.dk/business/2009-10-26-aktier-c20-trodser-plusser-i-udlandet
# Scraping article 80/100: https://nyheder.tv2.dk/business/2009-10-16-aktier-industriselskaberne-foerer-c20-frem
# Scraping article 81/100: https://nyheder.tv2.dk/business/2009-10-16-aktier-industriselskaberne-foerer-c20-frem
# Scraping article 82/100: https://nyheder.tv2.dk/business/2009-10-14-aktier-c20-buldrer-frem-med-norden-i-front
# Scraping article 83/100: https://nyheder.tv2.dk/business/2009-10-14-aktier-c20-passerer-kritisk-niveau-i-sikker-stil
# Scraping article 84/100: https://nyheder.tv2.dk/business/2009-10-12-aktier-c20-naermer-sig-igen-det-besvaerlige-niveau
# Scraping article 85/100: https://nyheder.tv2.dk/business/2009-10-12-aktier-maersk-foerer-c20-mod-nyt-plus
# Scraping article 86/100: https://nyheder.tv2.dk/business/2009-10-08-aktier-gode-udenlandske-nyheder-loefter-c20
# Scraping article 87/100: https://nyheder.tv2.dk/business/2009-09-30-aktier-c20-skvulper-hoejere
# Scraping article 88/100: https://nyheder.tv2.dk/business/2009-09-28-aktier-medicinsk-jubel-uden-for-c20
# Scraping article 89/100: https://nyheder.tv2.dk/business/2009-09-25-aktier-danske-bank-og-maersk-traekker-c20-i-plus
# Scraping article 90/100: https://nyheder.tv2.dk/business/2009-09-25-aktier-danske-bank-novo-og-maersk-sikrede-c20plus
# Scraping article 91/100: https://nyheder.tv2.dk/business/2009-09-16-aktier-plusser-til-samtlige-c20selskaber
# Scraping article 92/100: https://nyheder.tv2.dk/business/2009-09-10-aktier-c20-har-skiftet-til-negativt-territorium
# Scraping article 93/100: https://nyheder.tv2.dk/business/2009-09-10-aktier-c20-bevaeger-sig-i-plus-for-september
# Scraping article 94/100: https://nyheder.tv2.dk/business/2009-09-10-aktier-c20-i-plus-for-femte-dag-i-traek
# Scraping article 95/100: https://nyheder.tv2.dk/business/2009-09-09-aktier-danisco-og-dsv-gror-fast-i-c20toppen
# Scraping article 96/100: https://nyheder.tv2.dk/business/2009-09-07-aktier-brede-stigninger-sender-igen-c20-over-330
# Scraping article 97/100: https://nyheder.tv2.dk/business/2009-09-04-aktier-c20-stopper-fire-dages-nedtur
# Scraping article 98/100: https://nyheder.tv2.dk/business/2009-08-28-aktier-maersk-slaebebaad-for-aarsrekord-til-c20
# Scraping article 99/100: https://nyheder.tv2.dk/business/2009-08-25-godt-regnskab-trak-c20-op
# Scraping article 100/100: https://nyheder.tv2.dk/business/2009-08-24-aktier-maersk-og-c20-har-kurs-mod-aarsrekord
# Scraping completed. Total articles scraped: 100
